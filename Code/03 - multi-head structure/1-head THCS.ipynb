# %% [markdown]
# # THCS
# - 1 head
# - multi-head structure evaluation

# %%
import warnings
warnings.filterwarnings("ignore")
import time
import os
import numpy as np
import pandas as pd
from collections import OrderedDict
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import scipy.stats as st

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import scipy

import sys
sys.path.append("..")
from redo_handy_utils import *
from redo_utils import *
from dl_utils import *

from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

# %%
# CUDA support 
if torch.cuda.is_available():
    device = torch.device('cuda:1')
else:
    device = torch.device('cpu')

# tensorboard path
basepath = '/home/wengqy20/ML - work'
model_path = '06 - PINN/07 - code github/03 - multi-head structure'
log_path = '06 - PINN/07 - code github/03 - multi-head structure/tensorboard'
date_suf = 'THCS - ' + datetime.now().strftime("%Y%m%d - %H%M%S")
writer = SummaryWriter(os.path.join(basepath, log_path,  date_suf))

# %% [markdown]
# ## Network framework

# %%
# DNN
class DNN(torch.nn.Module):
    def __init__(self, layers):
        '''
        Args:
        layers  ::  array-like, number of neurons in each layer of the neural network
        
        '''
        super(DNN, self).__init__()
        # Network depth
        self.depth = len(layers) - 1
        
        # activation function
        # self.activation = torch.nn.ReLU
        self.activation = torch.nn.Tanh
        
        layer_list = list()
        # hidden layer
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
        # output layer
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        self.layers = torch.nn.Sequential(layerDict).to(device)
        
    def forward(self, x):
        out = self.layers(x)
        return out

def initialize_net(net):
    net_name = net.__class__.__name__                               # 2
    if net_name.find('layer') != -1:                                              
        nn.init.xavier_normal_(net.weight)
        nn.init.xavier_normal_(net.bias)

# %%
# THCS
class THCS():
    def __init__(self, X_eq, U_eq, X_gap, U_gap, X_nw, T_nw, model, prop_net, **kargs):
        '''
        Args:
        X_eq     ::  2d array, coordinate of scarce samples used for label loss
        U_eq     ::  2d array, physical parameters of scarce samples used for label loss
        X_gap    ::  2d array, coordinate of scarce samples used for equation loss
        U_gap    ::  2d array, physical parameters of scarce samples used for equation loss
        X_nw     ::  2d array, coordinate of scarce samples used for wall-temperature loss
        T_nw     ::  2d array, temperature of scarce samples used for wall-temperature loss
        model    ::  pkl, THCS model
        prop_net ::  pkl, MLP for thermal property mapping
        
        '''
        
        self.X_eq = torch.tensor(X_eq, requires_grad=True).float().to(device)
        self.U_eq = torch.tensor(U_eq, requires_grad=True).float().to(device)
        self.X_gap = torch.tensor(X_gap, requires_grad=True).float().to(device)
        self.U_gap = torch.tensor(U_gap, requires_grad=True).float().to(device)
        self.X_nw = torch.tensor(X_nw, requires_grad=True).float().to(device)
        self.T_nw = torch.tensor(T_nw, requires_grad=True).float().to(device)
        self.dnn = model
        self.prop_net = prop_net
        self.lb_T = kargs['T_lb']  # lower bound for the input of property network
        self.ub_T = kargs['T_ub']  # upper bound for the input of property network
        self.prop_cof = kargs['prop_cof']  # coefficient for property network
        self.T_pc = kargs['Tpc']  # pseudo-critical temperature
        self.ub = torch.tensor(kargs['ub'], requires_grad=True).float().to(device)  # lower bound for the input of main network
        self.lb = torch.tensor(kargs['lb'], requires_grad=True).float().to(device)  # upper bound for the input of main network
        self.loss_weight = kargs['loss_weight']  # weights of loss function

        self.u_eq = self.U_eq[:, 0:1]
        self.v_eq = self.U_eq[:, 1:2]
        self.T_eq = self.U_eq[:, 2:3]
        self.p_eq = self.U_eq[:, 7:8]
        self.data_0d = kargs['data_0d']
        self.fluid = 'CO2'

        # Dimensionless number
        self.T0 = self.data_0d.loc[0, 'T0']
        self.L0 = self.data_0d.loc[0, 'L0']
        self.U0 = self.data_0d.loc[0, 'U0']
        self.D0 = self.data_0d.loc[0, 'D0']
        self.M0 = self.data_0d.loc[0, 'M0']
        self.k0 = self.data_0d.loc[0, 'k0']
        self.Cp0 = self.data_0d.loc[0, 'Cp0']
        self.hpc = self.data_0d.loc[0, 'hpc'] /self.Cp0/self.T0
        self.prop_scl = [self.prop_cof[0]/self.D0, self.prop_cof[1]/self.M0, self.prop_cof[2]/self.k0, self.prop_cof[3]/self.Cp0/self.T0]  # scale factor for property network

        self.gx = -9.8  # upward flow
        self.Fr = self.U0**2 / (self.gx * self.L0)
        self.Re = self.D0 * self.U0 * self.L0 / self.M0
        self.Pr = self.M0 * self.Cp0 * self.k0
       
        self.iter = 0

    # physical field prediction by main network
    def net_pd(self, x, r):
        """
        Args:
        x   ::  array-like or float, dimensionless x-coordinate
        r   ::  array-like or float, dimensionless r-coordinate

        Return:
        u   ::  array-like or float, dimensionless streamwise velocity
        v   ::  array-like or float, dimensionless radial velocity
        p   ::  array-like or float, dimensionless hydraulic pressure
        T   ::  array-like or float, dimensionless Temperature

        """
        x_scl = 2.0*(x - self.lb[0])/(self.ub[0] - self.lb[0]) - 1.0
        r_scl = 2.0*(r - self.lb[1])/(self.ub[1] - self.lb[1]) - 1.0
        X_scl = torch.concat((x_scl, r_scl), dim=1)
        field = self.dnn(X_scl)
        u_d, v_d, p, T, Mt, kt = field[:, 0:1], field[:, 1:2], field[:, 2:3], field[:, 3:4], field[:, 4:5], field[:, 5:6]
        # hard manner for no-slip condition
        u = (1-r)*u_d
        v = (1-r)*v_d
        return u, v, p, T, Mt, kt

    # thermal property prediction by property network
    def prop_pd(self, T):
        """
        Args:
        T   ::  array-like or float, dimensionless temperature

        Return:
        D   ::  array-like or float, dimensionless density
        M   ::  array-like or float, dimensionless viscosity
        k   ::  array-like or float, dimensionless conductivity
        h   ::  array-like or float, dimensionless enthalpy

        """
        T_dim = self.T0 * T  # Dimensionalization
        T_scl = 2.0*(T_dim - self.lb_T)/(self.ub_T - self.lb_T) - 1.0
        prop_dim = self.prop_net(T_scl)
        D, M, k, h = self.prop_scl[0]*prop_dim[:, 0:1], self.prop_scl[1]*prop_dim[:, 1:2], self.prop_scl[2]*prop_dim[:, 2:3], self.prop_scl[3]*prop_dim[:, 3:4] - self.hpc
        
        return D, M, k, h
    
    # heat flux prediction
    def qw_pd(self, T, r):
        """
        Args:
        T   ::  array-like or float, dimensionless temperature
        r   ::  array-like or float, dimensionless r-coordinate

        Return:
        qw  ::  array-like or float, dimensionless heat flux

        """
        D, M, k, h = self.prop_pd(T)
        T_y = torch.autograd.grad(
            T, r, 
            grad_outputs=torch.ones_like(T),
            retain_graph=True,
            create_graph=True
            )[0]
        qw = k*T_y
        
        return qw

    # equation loss prediction
    def net_eq(self, x, r):
        """ 

        Thermal properties involved in equation losses are mean values in the whole domain.

        """

        u, v, p, T, Mt, kt = self.net_pd(x, r)
        D, M, k, h = self.prop_pd(T)

        Du_x = torch.autograd.grad(
            D*u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
            )[0]
        Dv_r = torch.autograd.grad(
            D*v, r, 
            grad_outputs=torch.ones_like(v),
            retain_graph=True,
            create_graph=True
            )[0]


        u_x = torch.autograd.grad(
            u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
            )[0]
        u_r = torch.autograd.grad(
            u, r, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
            )[0]

        v_x = torch.autograd.grad(
            v, x, 
            grad_outputs=torch.ones_like(v),
            retain_graph=True,
            create_graph=True
            )[0] 
        v_r = torch.autograd.grad(
            v, r, 
            grad_outputs=torch.ones_like(v),
            retain_graph=True,
            create_graph=True
            )[0]

        p_x = torch.autograd.grad(
            p, x, 
            grad_outputs=torch.ones_like(p),
            retain_graph=True,
            create_graph=True
            )[0]
        p_r = torch.autograd.grad(
            p, r, 
            grad_outputs=torch.ones_like(p),
            retain_graph=True,
            create_graph=True
            )[0]


        divU = u_x + (v_r + v/r)  # divergence
        # shear stress 
        shear_xx = 2*(M+Mt) * (u_x - divU/3)
        shear_xr = (M+Mt) * (v_x + u_r)
        shear_rr = 2*(M+Mt) * (v_r - divU/3)
        shear_xx_x = torch.autograd.grad(
            shear_xx, x, 
            grad_outputs=torch.ones_like(shear_xx),
            retain_graph=True,
            create_graph=True
            )[0] 
        shear_xr_r = torch.autograd.grad(
            r*shear_xr, r, 
            grad_outputs=torch.ones_like(shear_xr),
            retain_graph=True,
            create_graph=True
            )[0]
        shear_rx_x = torch.autograd.grad(
            shear_xr, x, 
            grad_outputs=torch.ones_like(shear_xr),
            retain_graph=True,
            create_graph=True
            )[0]
        shear_rr_r = torch.autograd.grad(
            r*shear_rr, r, 
            grad_outputs=torch.ones_like(shear_rr),
            retain_graph=True,
            create_graph=True
            )[0]

        T_x = torch.autograd.grad(
            T, x, 
            grad_outputs=torch.ones_like(T),
            retain_graph=True,
            create_graph=True
            )[0]
        T_r = torch.autograd.grad(
            T, r, 
            grad_outputs=torch.ones_like(T),
            retain_graph=True,
            create_graph=True
            )[0]
        h_x = torch.autograd.grad(
            h, x, 
            grad_outputs=torch.ones_like(h),
            retain_graph=True,
            create_graph=True
            )[0]
        h_r = torch.autograd.grad(
            h, r, 
            grad_outputs=torch.ones_like(h),
            retain_graph=True,
            create_graph=True
            )[0]
        # heat flux
        q_x = (k+kt) * T_x
        q_r = (k+kt) * T_r
        q_xx = torch.autograd.grad(
            q_x, x, 
            grad_outputs=torch.ones_like(q_x),
            retain_graph=True,
            create_graph=True
            )[0]
        q_rr = torch.autograd.grad(
            r*q_r, r, 
            grad_outputs=torch.ones_like(q_r),
            retain_graph=True,
            create_graph=True
            )[0]

        eq_m = Du_x + (Dv_r + D*v/r)  # mass conservation
        eq_u = D*u*u_x + D*v*u_r + p_x - 1/self.Re * (shear_xx_x + shear_xr_r/r) - D/self.Fr  # momentum conservation at direction of x
        eq_v = D*u*v_x + D*v*v_r + p_r - 1/self.Re * (shear_rx_x + shear_rr_r/r - 2*M/r*(v/r - divU/3))  # momentum conservation at direction of r
        eq_T = D*u*h_x + D*v*h_r - 1/self.Re/self.Pr * (q_xx + q_rr/r)  # energy conservation
        return eq_m, eq_u, eq_v, eq_T

    def loss_cal(self):
        eq_m, eq_u, eq_v, eq_T = self.net_eq(self.X_gap[:, 0:1], self.X_gap[:, 1:2])  # equation loss
        r_qt = self.X_eq[:, 1:2]
        u_pred, v_pred, p_pred, T_pred, Mt_pred, kt_pred = self.net_pd(self.X_eq[:, 0:1], r_qt)  # label loss
        u_pred_nw, v_pred_nw, p_pred_nw, T_pred_nw, Mt_pred_nw, kt_pred_nw = self.net_pd(self.X_nw[:, 0:1], self.X_nw[:, 1:2])  # loss of wall temperature, not adopted here

        # loss weight
        l_eq_m, l_eq_u, l_eq_v, l_eq_T = self.loss_weight['loss_eq_m'], self.loss_weight['loss_eq_u'], self.loss_weight['loss_eq_v'], self.loss_weight['loss_eq_T']
        l_u_eq, l_v_eq, l_T_eq, l_p_eq = self.loss_weight['loss_u_eq'], self.loss_weight['loss_v_eq'], self.loss_weight['loss_T_eq'], self.loss_weight['loss_p_eq']
        l_T_nw = self.loss_weight['loss_T_nw']


        loss_eq_m = l_eq_m * torch.mean(eq_m**2)
        loss_eq_u = l_eq_u * torch.mean(eq_u**2)
        loss_eq_v = l_eq_v * torch.mean(eq_v**2)
        loss_eq_T = l_eq_T * torch.mean(eq_T**2)

        # when close to the Tpc, increase the weight
        idx_Tpc = (abs(self.T_eq - self.T_pc) < 0.03)
        weight_pc = 1
        loss_u_eq = l_u_eq * (torch.mean(((u_pred - self.u_eq)[~idx_Tpc]**2)) + weight_pc*torch.mean(((u_pred - self.u_eq)[idx_Tpc]**2)))
        loss_v_eq = l_v_eq * (torch.mean((1e3*(v_pred - self.v_eq)[~idx_Tpc]**2)) + weight_pc*torch.mean((1e3*(v_pred - self.v_eq)[idx_Tpc]**2)))
        loss_T_eq = l_T_eq * (torch.mean(((T_pred - self.T_eq)[~idx_Tpc]**2)) + weight_pc*torch.mean(((T_pred - self.T_eq)[idx_Tpc]**2)))
        loss_p_eq = l_p_eq * (torch.mean((1e-2*(p_pred - self.p_eq)[~idx_Tpc]**2)) + weight_pc*torch.mean((1e-2*(p_pred - self.p_eq)[idx_Tpc]**2)))
        loss_T_nw = l_T_nw * torch.mean((T_pred_nw - self.T_nw)**2)
        loss_u = loss_u_eq + loss_v_eq
        loss_p = loss_p_eq
        loss_T = loss_T_eq +  loss_T_nw
        loss_eq = loss_eq_m + loss_eq_u + loss_eq_v + loss_eq_T 
        loss = loss_u + loss_T + loss_eq + loss_p

        # record loss in tensorboard
        writer.add_scalar('Loss_eq_m', loss_eq_m, self.iter)
        writer.add_scalar('Loss_eq_u', loss_eq_u, self.iter)
        writer.add_scalar('Loss_eq_v', loss_eq_v, self.iter)
        writer.add_scalar('Loss_eq_T', loss_eq_T, self.iter)
        writer.add_scalar('Loss_T_eq', loss_T_eq, self.iter)
        writer.add_scalar('Loss_u_eq', loss_u_eq, self.iter)
        writer.add_scalar('Loss_v_eq', loss_v_eq, self.iter)
        writer.add_scalar('Loss_p_eq', loss_p_eq, self.iter)
        writer.add_scalar('Loss_T_nw', loss_T_nw, self.iter)
        writer.add_scalar('Loss_u', loss_u, self.iter)
        writer.add_scalar('Loss_T', loss_T, self.iter)
        writer.add_scalar('Loss_eq', loss_eq, self.iter)
        writer.add_scalar('Loss', loss, self.iter)

        # print loss
        self.iter += 1
        if self.iter % 50 == 0:
            print('Iteration %d: loss: %.2e' %(self.iter, loss))
            print('loss_eq_m: %.2e, loss_eq_u: %.2e, loss_eq_v: %.2e, loss_eq_T: %.2e' %(loss_eq_m, loss_eq_u, loss_eq_v, loss_eq_T))
            print('loss_u_eq: %.2e, loss_v_eq: %.2e, loss_T_eq: %.2e, loss_p_eq: %.2e, loss_T_nw: %.2e' %(loss_u_eq, loss_v_eq, loss_T_eq, loss_p_eq, loss_T_nw))

        return loss

    # model training
    def train(self, iterat, optimizer_Adam, min_lr, patience):
        self.optimizer_Adam = optimizer_Adam
        tic = time.time()
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer_Adam, factor=0.6, patience=patience, min_lr=min_lr)
        for i in range(iterat):
            loss = self.loss_cal()
            loss.backward() 
            self.optimizer_Adam.step()
            self.optimizer_Adam.zero_grad()
            scheduler.step(loss)
            writer.add_scalar('Learning rate', self.optimizer_Adam.state_dict()['param_groups'][0]['lr'], self.iter)

        toc = time.time()
        print('Adam training time: %.2fs' %(toc - tic))

        return

    # predict physical fields
    def predict(self, X):
        X = torch.tensor(X, requires_grad=True).float().to(device)
        x, r= X[:, 0:1], X[:, 1:2]
        self.dnn.eval()
        u, v, p, T, Mt, kt = self.net_pd(x, r)
        u = u.detach().cpu().numpy()
        v = v.detach().cpu().numpy()
        p = p.detach().cpu().numpy()
        T = T.detach().cpu().numpy()
        Mt = Mt.detach().cpu().numpy()
        kt = kt.detach().cpu().numpy()
        return u, v, p, T, Mt, kt

    # predict thermal properties
    def predict_prop(self, T):
        """
        Args:
        T   ::  array-like or float, dimensionless Temperature

        Return:
        D   ::  array-like or float, dimensionless density
        M   ::  array-like or float, dimensionless viscosity
        k   ::  array-like or float, dimensionless conductivity
        h   ::  array-like or float, dimensionless enthalpy
        """

        T = torch.tensor(T, requires_grad=True).float().to(device)
        D, M, k, h = self.prop_pd(T)
        D = D.detach().cpu().numpy()
        M = M.detach().cpu().numpy()
        k = k.detach().cpu().numpy()
        h = h.detach().cpu().numpy()
        return D, M, k, h

    # predict heat flux 
    def predict_qw(self, X):
        X = torch.tensor(X, requires_grad=True).float().to(device)
        x, r= X[:, 0:1], X[:, 1:2]
        self.dnn.eval()
        u, v, p, T, Mt, kt = self.net_pd(x, r)
        qw = self.qw_pd(T, r)
        qw = qw.detach().cpu().numpy()
        return qw

# %% [markdown]
# ## Data process

# %% [markdown]
# ### Thermal property prediction

# %%
layers_prop = [1, 20, 20, 20, 20, 20, 4]
prop_net = DNN(layers_prop)
prop_net.load_state_dict(torch.load(os.path.join(basepath, model_path, 'Prop_6layers(20)_6props_0121_8800kPa_CO2.pkl')))
Tlb, Tub = 200, 600  # CO2

prop_cof = [1e3, 1e-4, 1e-1, 1e5]

# %% [markdown]
# ### Load data

# %%
fluid = 'CO2'
Tpc = 312.11536057680286
Tref = 800
L0, T0, Re0, p_in = 0.496e-3, 297.55, 1900.0, 8.8e6
D0 = property_from_NIST('Dmass', T0, p_in, fluid)
Cp0 = property_from_NIST('Cpmass', T0, p_in, fluid)
M0 = property_from_NIST('viscosity', T0, p_in, fluid)
k0 = property_from_NIST('conductivity', T0, p_in, fluid)
U0 = Re0*M0/(D0*L0)
hpc = property_from_NIST('Hmass', Tpc, p_in, fluid)

# %%
idx = 0
data_path_dns = [
    '02 - data/DNS_data/CaoYuli/P8.8q549d99.mat',
    ]

N_wc_dns = len(data_path_dns)
dns_data = pd.DataFrame()

data_2d_dns = {}
data_0d_dns, data_1d_dns = pd.DataFrame(), pd.DataFrame()
data_2d_wc = {}
dns_temp = scipy.io.loadmat(os.path.join(basepath, data_path_dns[idx]))

r_dns = dns_temp['y'].reshape(-1)
y_dns = 1 - r_dns
x_dns = 2*dns_temp['x'].reshape(-1)


drop_feats = ['__header__', '__version__', '__globals__', 'A', 'ans', 'N1', 'N2', 'Nk', 'NX', 'NY', 'R_IO', 'ReN', 'str', 'time1', 'time2', 'table', 'temp', 'data1', 'data2', 'data3', 'data4', 'dummy_thel',  'dummy1_thel', 'dummy2_thel', 'dummyline', 'fid1', 'fid2', 'fid3', 'fid4',  'RLEMPI1_thel', 'RLEMPI2_thel', 'i', 'j', 'k', 'J', 'y', 'xx', 'xND', 'len', 'dummy', 'dummy1', 'dummy2', 'RLEMPI1', 'RLEMPI2', 'a', 'dummy1_flow', 'dummy_flow', 'dummy2_flow', 'fid5', 'fid6', 'fid7', 'RLEMPI1_FLOW', 'RLEMPI2_FLOW']
for d_f in drop_feats:
    if d_f in dns_temp.keys():
        del dns_temp[d_f]

# Classify variables with different dimension
data_0d_temp, data_1d_temp = pd.DataFrame(np.zeros(1)), pd.DataFrame(np.zeros(len(dns_temp['x'][0])))
for feat,data in dns_temp.items():
    # Scalar
    if data.shape[1] == 1:
        data_0d_temp[feat] = data[0][0]

    # 1d-array
    elif data.shape[0] == 1:
        data_1d_temp[feat] = data[0]
    
    # 2d-array
    elif len(data.shape) == 2:
        data_2d_wc[feat] = pd.DataFrame(data)
        data_2d_wc[feat].columns = r_dns

data_0d_temp['P0'] = p_in
data_0d_temp['Re0'] = Re0
data_0d_temp['U0'] = data_0d_temp['Re0'] * data_0d_temp['M0'] / data_0d_temp['D0'] / (2*data_0d_temp['L0'])
data_0d_temp['h0'] = property_from_NIST('Hmass', data_0d_temp.loc[0, 'T0'], data_0d_temp.loc[0, 'P0'], 'CO2')
data_0d_temp['hpc'] = property_from_NIST('Hmass', Tpc, data_0d_temp.loc[0, 'P0'], 'CO2')
data_0d_temp['href'] = property_from_NIST('Hmass', Tref, data_0d_temp.loc[0, 'P0'], 'CO2')
data_0d_temp.drop(columns=0, inplace=True)
data_1d_temp.drop(columns=0, inplace=True)
data_0d_temp['wc_idx'] = idx
data_1d_temp['wc_idx'] = idx

data_1d_temp.insert(0, 'x/r', 2*data_1d_temp['x'])
data_1d_temp.drop(columns='x', inplace=True)
data_1d_temp['Tw'] = data_2d_wc['T_Re'].iloc[:, -1].values

data_0d_dns = pd.concat((data_0d_dns, data_0d_temp))
data_1d_dns = pd.concat((data_1d_dns, data_1d_temp))
data_2d_dns[idx] = data_2d_wc
    
data_0d_dns.reset_index(drop=True, inplace=True)
data_1d_dns.reset_index(drop=True, inplace=True)

# %%
# 2d data
x_star_dns = data_1d_dns['x/r'].unique()[:, None]  # Nx x 1
r_star_dns = r_dns[:,None]  # Ny x 1
X_dns, R_dns = np.meshgrid(x_star_dns, r_star_dns, indexing='ij')  # Nx x Ny
X_star_dns = np.hstack((X_dns.flatten('F')[:,None], R_dns.flatten('F')[:,None]))  # NxNyNq x 3


data_2d_dns = data_2d_dns[idx]
u_dns = data_2d_dns['Ux_Re'].to_numpy()  # Nx x Ny
v_dns = data_2d_dns['Uy_Re'].to_numpy()  # Nx x Ny
p_dns = data_2d_dns['P_Re'].to_numpy()  # Nx x Ny
T_dns = data_2d_dns['T_Re'].to_numpy()  # Nx x Ny
D_dns = data_2d_dns['D_Re'].to_numpy()  # Nx x Ny
M_dns = data_2d_dns['M_Re'].to_numpy()  # Nx x Ny
k_dns = data_2d_dns['K_Re'].to_numpy()  # Nx x Ny
# the original temperature of enthalpy is 800K
h_dns = data_2d_dns['H_Re'].to_numpy() + (data_0d_dns.loc[0, 'href']-data_0d_dns.loc[0, 'hpc'])/(data_0d_dns.loc[0, 'T0']*data_0d_dns.loc[0, 'Cp0']) # Nx x Ny

u_star_dns = u_dns.flatten('F')[:,None]  # NxNyNq x 1
v_star_dns = v_dns.flatten('F')[:,None]  # NxNyNq x 1
p_star_dns = p_dns.flatten('F')[:,None]  # NxNyNq x 1
h_star_dns = h_dns.flatten('F')[:,None]  # NxNyNq x 1
T_star_dns = T_dns.flatten('F')[:,None]  # NxNyNq x 1
D_star_dns = D_dns.flatten('F')[:,None]  # NxNyNq x 1
M_star_dns = M_dns.flatten('F')[:,None]  # NxNyNq x 1
k_star_dns = k_dns.flatten('F')[:,None]  # NxNyNq x 1

U_star_dns = np.array([])
U_star_dns = np.hstack((u_star_dns, v_star_dns, T_star_dns, D_star_dns, M_star_dns, k_star_dns, h_star_dns, p_star_dns))  # NxNyNq x 9

# %%
# random seed
set_seed(1)

# training set
N_eq = 1000  # number of data for label loss
N_gap = 200  # number of data for equation loss
lb_dns = np.array([0.0, 0.0])  # lower bound for input coordinates
ub_dns = np.array([240.0, 1.0])  # upper bound for input coordinates

X_eq_dns, U_eq_dns = np.array([]), np.array([])
X_train = X_star_dns[(X_star_dns[:, 0] <= 236)]
U_train = U_star_dns[(X_star_dns[:, 0] <= 236)]

# For more uniform sampling, 30% data are in the near-wall region (r >= 0.8)
wall_bd = 0.8
test_pc = 0.3
X_core_train = X_train[((X_train[:, 1] < wall_bd))]
X_wall_train = X_train[(X_train[:, 1] >= wall_bd)]
U_core_train = U_train[((X_train[:, 1] < wall_bd))]
U_wall_train = U_train[(X_train[:, 1] >= wall_bd)]
idx_eq_core = np.random.choice(X_core_train.shape[0], int(N_eq*(1-test_pc)), replace=False)
idx_eq_wall = np.random.choice(X_wall_train.shape[0], int(N_eq*test_pc), replace=False)
X_eq_dns = np.vstack((X_core_train[idx_eq_core], X_wall_train[idx_eq_wall]))
U_eq_dns = np.vstack((U_core_train[idx_eq_core], U_wall_train[idx_eq_wall]))

X_core_test = X_train[((X_train[:, 1] < wall_bd))]
X_wall_test = X_train[(X_train[:, 1] >= wall_bd)]
U_core_test = U_train[((X_train[:, 1] < wall_bd))]
U_wall_test = U_train[(X_train[:, 1] >= wall_bd)]
idx_eq_core = np.random.choice(X_core_test.shape[0], int(N_gap*(1-test_pc)), replace=False)
idx_eq_wall = np.random.choice(X_wall_test.shape[0], int(N_gap*test_pc), replace=False)
X_gap_dns = np.vstack((X_core_test[idx_eq_core], X_wall_test[idx_eq_wall]))
U_gap_dns = np.vstack((U_core_test[idx_eq_core], U_wall_test[idx_eq_wall]))


# wall temperature sampling
## N_nw is the number of data sampled in the direction of r
## N_b is the number of data sampled in the direction of x
N_nw, N_b = 1, 10 
idx_b = np.array([int(x) for x in np.linspace(0, x_dns.shape[0], N_b)])   # uniform distribution
for j in range(N_b):
    X_temp = X_star_dns[(X_star_dns[:, 0]==x_dns[idx_b[j]])&(X_star_dns[:, 1]>=r_dns[-N_nw])]
    T_temp = U_star_dns[(X_star_dns[:, 0]==x_dns[idx_b[j]])&(X_star_dns[:, 1]>=r_dns[-N_nw]), 2][:,None]
    if j == 0:
        X_nw_dns = X_temp
        T_nw_dns = T_temp
    else:
        X_nw_dns = np.vstack((X_nw_dns, X_temp))
        T_nw_dns = np.vstack((T_nw_dns, T_temp))

# %% [markdown]
# ## Model training

# %% [markdown]
# ###  Network construction

# %%
# NN size
layers = [2, 36, 36, 36, 36, 36, 36, 36, 6]
dnn = DNN(layers)

# Initialize or load the model
LOADMODEL = True
# LOADMODEL = False
if LOADMODEL:
    dnn.load_state_dict(torch.load(os.path.join(basepath, model_path, '10layers(36)_THCS 1-head.pkl')))
else:
    dnn.apply(initialize_net)

# %%
loss_weight = {
    'loss_eq_m':1e4, 'loss_eq_u':1e4, 'loss_eq_v':1e3, 'loss_eq_T':1e6, 
    'loss_u_ub':1e0, 'loss_v_ub':1e0, 'loss_T_ub':1e0,
    'loss_u_lb':1e0, 'loss_v_lb':1e0, 'loss_T_lb':1e0,
    'loss_u_0':1e0, 'loss_v_0':1e0, 'loss_T_0':1e0,
    'loss_u_eq':1e5, 'loss_v_eq':1e4, 'loss_T_eq':1e7, 'loss_p_eq':0, 'loss_T_nw':0,
    'loss_qw':0,
    }
thcs = THCS(X_eq_dns, U_eq_dns, X_gap_dns, U_gap_dns, X_nw_dns, T_nw_dns, dnn, prop_net, lb=lb_dns, ub=ub_dns, loss_weight=loss_weight, data_0d=data_0d_dns, T_lb=Tlb, T_ub=Tub, prop_cof=prop_cof, Tpc=Tpc/T0)

# %% [markdown]
# ### Training process

# %%
num_epochs = 40000
thcs.train(num_epochs, optim.Adam(dnn.parameters(), lr=1e-4), min_lr=0.2e-4, patience=1000)
# Out:
# Iteration 100050: loss: 2.97e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.50e+01
# loss_u_eq: 9.22e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100100: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.20e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100150: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.30e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100200: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100250: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100300: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100350: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.35e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100400: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100450: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100500: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100550: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100600: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100650: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100700: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100750: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100800: loss: 2.94e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.29e+01
# loss_u_eq: 9.16e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100850: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.16e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100900: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.16e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 100950: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.15e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101000: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.15e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101050: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.15e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101100: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.14e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101150: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.28e+01
# loss_u_eq: 9.14e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101200: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.13e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101250: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.13e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101300: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.16e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.13e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101350: loss: 2.93e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.12e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101400: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.12e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101450: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.11e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101500: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.26e+01
# loss_u_eq: 9.11e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101550: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.26e+01
# loss_u_eq: 9.10e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101600: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.26e+01
# loss_u_eq: 9.10e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101650: loss: 2.93e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.82e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.34e+01
# loss_u_eq: 9.09e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101700: loss: 2.92e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.27e+01
# loss_u_eq: 9.08e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101750: loss: 2.96e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.63e+01
# loss_u_eq: 9.10e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101800: loss: 2.92e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.25e+01
# loss_u_eq: 9.07e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101850: loss: 2.95e+02
# loss_eq_m: 4.36e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.51e+01
# loss_u_eq: 9.08e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101900: loss: 2.91e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.24e+01
# loss_u_eq: 9.06e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 101950: loss: 2.92e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.30e+01
# loss_u_eq: 9.06e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102000: loss: 2.91e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.24e+01
# loss_u_eq: 9.05e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102050: loss: 2.91e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.15e-03, loss_eq_T: 5.24e+01
# loss_u_eq: 9.05e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102100: loss: 2.91e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.25e+01
# loss_u_eq: 9.04e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102150: loss: 2.91e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.23e+01
# loss_u_eq: 9.04e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102200: loss: 2.92e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.84e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.40e+01
# loss_u_eq: 9.03e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102250: loss: 2.91e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.25e+01
# loss_u_eq: 9.03e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102300: loss: 2.90e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.22e+01
# loss_u_eq: 9.02e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102350: loss: 2.90e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.23e+01
# loss_u_eq: 9.01e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102400: loss: 2.90e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.24e+01
# loss_u_eq: 9.01e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102450: loss: 2.90e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.21e+01
# loss_u_eq: 9.00e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102500: loss: 3.01e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.67e-01, loss_eq_v: 1.14e-03, loss_eq_T: 6.18e+01
# loss_u_eq: 9.04e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.34e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102550: loss: 2.90e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.21e+01
# loss_u_eq: 8.99e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102600: loss: 2.90e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.21e+01
# loss_u_eq: 8.99e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102650: loss: 2.90e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.14e-03, loss_eq_T: 5.21e+01
# loss_u_eq: 8.98e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102700: loss: 2.90e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.21e+01
# loss_u_eq: 8.98e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102750: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.20e+01
# loss_u_eq: 8.97e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102800: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.20e+01
# loss_u_eq: 8.97e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102850: loss: 2.93e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.55e+01
# loss_u_eq: 8.97e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102900: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.20e+01
# loss_u_eq: 8.95e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 102950: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.19e+01
# loss_u_eq: 8.95e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103000: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.20e+01
# loss_u_eq: 8.94e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103050: loss: 2.89e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.18e+01
# loss_u_eq: 8.94e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103100: loss: 2.88e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.18e+01
# loss_u_eq: 8.93e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103150: loss: 2.89e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.22e+01
# loss_u_eq: 8.93e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103200: loss: 2.88e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.18e+01
# loss_u_eq: 8.92e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103250: loss: 2.88e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.13e-03, loss_eq_T: 5.17e+01
# loss_u_eq: 8.92e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103300: loss: 2.89e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.23e+01
# loss_u_eq: 8.91e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103350: loss: 2.88e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.17e+01
# loss_u_eq: 8.91e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103400: loss: 2.88e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.17e+01
# loss_u_eq: 8.90e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103450: loss: 2.88e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.17e+01
# loss_u_eq: 8.89e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103500: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.16e+01
# loss_u_eq: 8.89e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103550: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.16e+01
# loss_u_eq: 8.88e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103600: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.16e+01
# loss_u_eq: 8.88e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103650: loss: 2.95e+02
# loss_eq_m: 4.43e-01, loss_eq_u: 4.90e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.98e+01
# loss_u_eq: 8.90e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103700: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.15e+01
# loss_u_eq: 8.87e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103750: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.15e+01
# loss_u_eq: 8.86e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103800: loss: 2.91e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.50e+01
# loss_u_eq: 8.87e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.33e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103850: loss: 2.87e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.14e+01
# loss_u_eq: 8.85e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103900: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.14e+01
# loss_u_eq: 8.85e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 103950: loss: 2.87e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.16e+01
# loss_u_eq: 8.84e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104000: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.13e+01
# loss_u_eq: 8.83e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104050: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.13e+01
# loss_u_eq: 8.83e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104100: loss: 2.91e+02
# loss_eq_m: 4.42e-01, loss_eq_u: 4.87e-01, loss_eq_v: 1.12e-03, loss_eq_T: 5.66e+01
# loss_u_eq: 8.84e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104150: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.13e+01
# loss_u_eq: 8.82e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104200: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.13e+01
# loss_u_eq: 8.81e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104250: loss: 2.86e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.12e+01
# loss_u_eq: 8.81e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104300: loss: 2.86e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.12e+01
# loss_u_eq: 8.80e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104350: loss: 2.88e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.84e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.37e+01
# loss_u_eq: 8.80e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104400: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.12e+01
# loss_u_eq: 8.79e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104450: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.12e+01
# loss_u_eq: 8.79e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104500: loss: 2.85e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.12e+01
# loss_u_eq: 8.78e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104550: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.10e+01
# loss_u_eq: 8.77e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104600: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.10e+01
# loss_u_eq: 8.77e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104650: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.11e+01
# loss_u_eq: 8.76e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104700: loss: 2.87e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.11e-03, loss_eq_T: 5.25e+01
# loss_u_eq: 8.77e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.32e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104750: loss: 2.85e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.75e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104800: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.75e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104850: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.74e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104900: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.74e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 104950: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.08e+01
# loss_u_eq: 8.73e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105000: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.73e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105050: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.72e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105100: loss: 2.84e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.10e+01
# loss_u_eq: 8.72e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105150: loss: 2.84e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.71e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105200: loss: 2.83e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.70e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105250: loss: 2.84e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.10e+01
# loss_u_eq: 8.70e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105300: loss: 2.83e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.69e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105350: loss: 2.83e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.69e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105400: loss: 2.83e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.11e+01
# loss_u_eq: 8.68e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105450: loss: 2.83e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.06e+01
# loss_u_eq: 8.68e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105500: loss: 2.84e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.19e+01
# loss_u_eq: 8.68e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105550: loss: 2.83e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.10e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.67e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105600: loss: 2.82e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.05e+01
# loss_u_eq: 8.66e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105650: loss: 2.82e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.05e+01
# loss_u_eq: 8.66e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105700: loss: 2.84e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.15e+01
# loss_u_eq: 8.66e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105750: loss: 2.82e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.04e+01
# loss_u_eq: 8.65e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105800: loss: 2.82e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.04e+01
# loss_u_eq: 8.64e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105850: loss: 2.82e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.78e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.08e+01
# loss_u_eq: 8.64e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105900: loss: 2.82e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.06e+01
# loss_u_eq: 8.63e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 105950: loss: 2.82e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.03e+01
# loss_u_eq: 8.63e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106000: loss: 2.85e+02
# loss_eq_m: 4.42e-01, loss_eq_u: 4.83e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.42e+01
# loss_u_eq: 8.63e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106050: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.02e+01
# loss_u_eq: 8.62e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106100: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.02e+01
# loss_u_eq: 8.61e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106150: loss: 2.81e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.04e+01
# loss_u_eq: 8.61e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106200: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.02e+01
# loss_u_eq: 8.60e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106250: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.02e+01
# loss_u_eq: 8.59e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106300: loss: 2.82e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.80e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.15e+01
# loss_u_eq: 8.59e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106350: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.01e+01
# loss_u_eq: 8.58e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106400: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.01e+01
# loss_u_eq: 8.58e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106450: loss: 2.81e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.57e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106500: loss: 2.80e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.57e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106550: loss: 2.88e+02
# loss_eq_m: 4.43e-01, loss_eq_u: 4.86e-01, loss_eq_v: 1.09e-03, loss_eq_T: 5.74e+01
# loss_u_eq: 8.59e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106600: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.56e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106650: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.55e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106700: loss: 2.82e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.13e+01
# loss_u_eq: 8.55e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106750: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.99e+01
# loss_u_eq: 8.54e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106800: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.54e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106850: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.76e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.00e+01
# loss_u_eq: 8.53e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106900: loss: 2.80e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.98e+01
# loss_u_eq: 8.53e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 106950: loss: 2.80e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.04e+01
# loss_u_eq: 8.53e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107000: loss: 2.79e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.99e+01
# loss_u_eq: 8.52e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107050: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.97e+01
# loss_u_eq: 8.51e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107100: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.97e+01
# loss_u_eq: 8.51e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107150: loss: 2.81e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.09e+01
# loss_u_eq: 8.51e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.30e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107200: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.97e+01
# loss_u_eq: 8.50e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107250: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.77e-01, loss_eq_v: 1.08e-03, loss_eq_T: 5.01e+01
# loss_u_eq: 8.49e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107300: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.08e-03, loss_eq_T: 4.96e+01
# loss_u_eq: 8.49e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107350: loss: 2.79e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.96e+01
# loss_u_eq: 8.48e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107400: loss: 2.78e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.96e+01
# loss_u_eq: 8.48e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107450: loss: 2.78e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.95e+01
# loss_u_eq: 8.47e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107500: loss: 2.89e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.62e-01, loss_eq_v: 1.07e-03, loss_eq_T: 5.84e+01
# loss_u_eq: 8.51e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.31e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107550: loss: 2.78e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.96e+01
# loss_u_eq: 8.46e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107600: loss: 2.78e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.95e+01
# loss_u_eq: 8.46e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107650: loss: 2.78e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.94e+01
# loss_u_eq: 8.45e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107700: loss: 2.78e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.95e+01
# loss_u_eq: 8.45e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107750: loss: 2.78e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.94e+01
# loss_u_eq: 8.44e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107800: loss: 2.78e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.75e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.99e+01
# loss_u_eq: 8.44e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107850: loss: 2.78e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.94e+01
# loss_u_eq: 8.43e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107900: loss: 2.77e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.93e+01
# loss_u_eq: 8.43e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 107950: loss: 2.77e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.93e+01
# loss_u_eq: 8.42e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108000: loss: 2.78e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.96e+01
# loss_u_eq: 8.42e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108050: loss: 2.77e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.93e+01
# loss_u_eq: 8.41e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108100: loss: 2.77e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.07e-03, loss_eq_T: 4.92e+01
# loss_u_eq: 8.41e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108150: loss: 2.80e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.66e-01, loss_eq_v: 1.07e-03, loss_eq_T: 5.16e+01
# loss_u_eq: 8.41e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108200: loss: 2.77e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.92e+01
# loss_u_eq: 8.40e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108250: loss: 2.77e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.91e+01
# loss_u_eq: 8.39e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108300: loss: 2.77e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.74e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.93e+01
# loss_u_eq: 8.39e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108350: loss: 2.76e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.91e+01
# loss_u_eq: 8.38e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108400: loss: 2.79e+02
# loss_eq_m: 4.42e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.06e-03, loss_eq_T: 5.20e+01
# loss_u_eq: 8.39e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108450: loss: 2.76e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.91e+01
# loss_u_eq: 8.37e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108500: loss: 2.76e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.90e+01
# loss_u_eq: 8.37e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108550: loss: 2.87e+02
# loss_eq_m: 4.45e-01, loss_eq_u: 4.85e-01, loss_eq_v: 1.06e-03, loss_eq_T: 5.96e+01
# loss_u_eq: 8.40e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108600: loss: 2.76e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.90e+01
# loss_u_eq: 8.36e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108650: loss: 2.76e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.89e+01
# loss_u_eq: 8.35e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108700: loss: 2.77e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.67e-01, loss_eq_v: 1.06e-03, loss_eq_T: 5.02e+01
# loss_u_eq: 8.35e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108750: loss: 2.75e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.89e+01
# loss_u_eq: 8.34e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108800: loss: 2.75e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.89e+01
# loss_u_eq: 8.34e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108850: loss: 2.76e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.94e+01
# loss_u_eq: 8.34e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108900: loss: 2.75e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.88e+01
# loss_u_eq: 8.33e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 108950: loss: 2.78e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.66e-01, loss_eq_v: 1.06e-03, loss_eq_T: 5.08e+01
# loss_u_eq: 8.33e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109000: loss: 2.75e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.89e+01
# loss_u_eq: 8.32e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109050: loss: 2.75e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.06e-03, loss_eq_T: 4.88e+01
# loss_u_eq: 8.31e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109100: loss: 2.79e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.81e-01, loss_eq_v: 1.06e-03, loss_eq_T: 5.33e+01
# loss_u_eq: 8.32e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109150: loss: 2.75e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.87e+01
# loss_u_eq: 8.31e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109200: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.87e+01
# loss_u_eq: 8.30e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109250: loss: 2.82e+02
# loss_eq_m: 4.36e-01, loss_eq_u: 4.61e-01, loss_eq_v: 1.05e-03, loss_eq_T: 5.52e+01
# loss_u_eq: 8.32e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109300: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.86e+01
# loss_u_eq: 8.29e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109350: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.86e+01
# loss_u_eq: 8.29e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109400: loss: 2.78e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.64e-01, loss_eq_v: 1.05e-03, loss_eq_T: 5.17e+01
# loss_u_eq: 8.30e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.29e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109450: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.86e+01
# loss_u_eq: 8.28e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109500: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.85e+01
# loss_u_eq: 8.27e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109550: loss: 2.77e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.65e-01, loss_eq_v: 1.05e-03, loss_eq_T: 5.07e+01
# loss_u_eq: 8.28e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109600: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.86e+01
# loss_u_eq: 8.26e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109650: loss: 2.74e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.85e+01
# loss_u_eq: 8.26e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109700: loss: 2.75e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.67e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.95e+01
# loss_u_eq: 8.26e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109750: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.85e+01
# loss_u_eq: 8.25e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109800: loss: 2.74e+02
# loss_eq_m: 4.41e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.89e+01
# loss_u_eq: 8.24e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109850: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.83e+01
# loss_u_eq: 8.24e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109900: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.73e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.88e+01
# loss_u_eq: 8.23e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 109950: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.83e+01
# loss_u_eq: 8.23e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110000: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.83e+01
# loss_u_eq: 8.22e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110050: loss: 2.73e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.67e-01, loss_eq_v: 1.05e-03, loss_eq_T: 4.88e+01
# loss_u_eq: 8.22e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110100: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.71e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.83e+01
# loss_u_eq: 8.22e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.28e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110150: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.84e+01
# loss_u_eq: 8.21e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110200: loss: 2.73e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.72e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.84e+01
# loss_u_eq: 8.21e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110250: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.82e+01
# loss_u_eq: 8.20e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110300: loss: 2.77e+02
# loss_eq_m: 4.42e-01, loss_eq_u: 4.79e-01, loss_eq_v: 1.04e-03, loss_eq_T: 5.26e+01
# loss_u_eq: 8.21e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110350: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.81e+01
# loss_u_eq: 8.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110400: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.81e+01
# loss_u_eq: 8.19e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110450: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.81e+01
# loss_u_eq: 8.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110500: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.80e+01
# loss_u_eq: 8.18e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110550: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.80e+01
# loss_u_eq: 8.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110600: loss: 2.72e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.80e+01
# loss_u_eq: 8.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110650: loss: 2.72e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.68e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.81e+01
# loss_u_eq: 8.17e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110700: loss: 2.71e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.70e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.80e+01
# loss_u_eq: 8.16e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110750: loss: 2.71e+02
# loss_eq_m: 4.39e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.79e+01
# loss_u_eq: 8.16e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110800: loss: 2.71e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.79e+01
# loss_u_eq: 8.15e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110850: loss: 2.71e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.79e+01
# loss_u_eq: 8.15e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110900: loss: 2.71e+02
# loss_eq_m: 4.40e-01, loss_eq_u: 4.69e-01, loss_eq_v: 1.04e-03, loss_eq_T: 4.78e+01
# loss_u_eq: 8.14e+01, loss_v_eq: 1.38e+01, loss_T_eq: 1.27e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 110950: loss: 2.71e+02
# ...
# loss_u_eq: 6.44e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136450: loss: 2.31e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.97e-04, loss_eq_T: 3.79e+01
# loss_u_eq: 6.44e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136500: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.96e-04, loss_eq_T: 3.78e+01
# loss_u_eq: 6.44e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136550: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.96e-04, loss_eq_T: 3.78e+01
# loss_u_eq: 6.44e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136600: loss: 2.32e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.95e-04, loss_eq_T: 3.79e+01
# loss_u_eq: 6.44e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136650: loss: 2.32e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.31e-01, loss_eq_v: 7.95e-04, loss_eq_T: 3.86e+01
# loss_u_eq: 6.43e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136700: loss: 2.31e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.95e-04, loss_eq_T: 3.78e+01
# loss_u_eq: 6.43e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136750: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.28e-01, loss_eq_v: 7.94e-04, loss_eq_T: 3.76e+01
# loss_u_eq: 6.43e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136800: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.28e-01, loss_eq_v: 7.94e-04, loss_eq_T: 3.76e+01
# loss_u_eq: 6.42e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136850: loss: 2.31e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.28e-01, loss_eq_v: 7.93e-04, loss_eq_T: 3.78e+01
# loss_u_eq: 6.42e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136900: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.27e-01, loss_eq_v: 7.93e-04, loss_eq_T: 3.75e+01
# loss_u_eq: 6.42e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 136950: loss: 2.33e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.22e-01, loss_eq_v: 7.94e-04, loss_eq_T: 3.96e+01
# loss_u_eq: 6.41e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137000: loss: 2.31e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.92e-04, loss_eq_T: 3.79e+01
# loss_u_eq: 6.42e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137050: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.28e-01, loss_eq_v: 7.92e-04, loss_eq_T: 3.76e+01
# loss_u_eq: 6.41e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137100: loss: 2.33e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.21e-01, loss_eq_v: 7.92e-04, loss_eq_T: 3.93e+01
# loss_u_eq: 6.42e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137150: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.91e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.41e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137200: loss: 2.32e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.31e-01, loss_eq_v: 7.92e-04, loss_eq_T: 3.91e+01
# loss_u_eq: 6.41e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137250: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.90e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.40e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137300: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.90e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.40e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137350: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.89e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.40e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137400: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.89e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.39e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137450: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.27e-01, loss_eq_v: 7.88e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.39e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137500: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.27e-01, loss_eq_v: 7.88e-04, loss_eq_T: 3.74e+01
# loss_u_eq: 6.39e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137550: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.88e-04, loss_eq_T: 3.73e+01
# loss_u_eq: 6.39e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137600: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.88e-04, loss_eq_T: 3.73e+01
# loss_u_eq: 6.39e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137650: loss: 2.30e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.87e-04, loss_eq_T: 3.75e+01
# loss_u_eq: 6.38e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137700: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.87e-04, loss_eq_T: 3.73e+01
# loss_u_eq: 6.38e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137750: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.86e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.38e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137800: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.86e-04, loss_eq_T: 3.73e+01
# loss_u_eq: 6.38e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137850: loss: 2.30e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.86e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.37e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137900: loss: 2.33e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.86e-04, loss_eq_T: 3.98e+01
# loss_u_eq: 6.38e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.15e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 137950: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.85e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.37e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138000: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.84e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.37e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138050: loss: 2.33e+02
# loss_eq_m: 4.38e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.86e-04, loss_eq_T: 4.12e+01
# loss_u_eq: 6.37e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138100: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.84e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.36e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138150: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.83e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.36e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138200: loss: 2.29e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.83e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.36e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138250: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.82e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.35e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138300: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.27e-01, loss_eq_v: 7.82e-04, loss_eq_T: 3.73e+01
# loss_u_eq: 6.35e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138350: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.26e-01, loss_eq_v: 7.82e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.35e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138400: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.81e-04, loss_eq_T: 3.70e+01
# loss_u_eq: 6.35e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138450: loss: 2.31e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.81e-04, loss_eq_T: 3.86e+01
# loss_u_eq: 6.35e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138500: loss: 2.29e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.80e-04, loss_eq_T: 3.70e+01
# loss_u_eq: 6.34e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138550: loss: 2.38e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.35e-01, loss_eq_v: 7.84e-04, loss_eq_T: 4.61e+01
# loss_u_eq: 6.37e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138600: loss: 2.29e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.80e-04, loss_eq_T: 3.70e+01
# loss_u_eq: 6.34e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138650: loss: 2.29e+02
# loss_eq_m: 4.36e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.80e-04, loss_eq_T: 3.77e+01
# loss_u_eq: 6.33e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138700: loss: 2.29e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.27e-01, loss_eq_v: 7.79e-04, loss_eq_T: 3.77e+01
# loss_u_eq: 6.34e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138750: loss: 2.30e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.79e-04, loss_eq_T: 3.83e+01
# loss_u_eq: 6.34e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138800: loss: 2.28e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.78e-04, loss_eq_T: 3.70e+01
# loss_u_eq: 6.33e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138850: loss: 2.30e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.78e-04, loss_eq_T: 3.78e+01
# loss_u_eq: 6.33e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138900: loss: 2.28e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.77e-04, loss_eq_T: 3.69e+01
# loss_u_eq: 6.32e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 138950: loss: 2.31e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.30e-01, loss_eq_v: 7.78e-04, loss_eq_T: 3.94e+01
# loss_u_eq: 6.33e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139000: loss: 2.28e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.77e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.32e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139050: loss: 2.31e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.18e-01, loss_eq_v: 7.77e-04, loss_eq_T: 3.88e+01
# loss_u_eq: 6.32e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139100: loss: 2.28e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.76e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.31e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139150: loss: 2.32e+02
# loss_eq_m: 4.31e-01, loss_eq_u: 4.17e-01, loss_eq_v: 7.77e-04, loss_eq_T: 4.03e+01
# loss_u_eq: 6.33e+01, loss_v_eq: 1.37e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139200: loss: 2.28e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.75e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.31e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139250: loss: 2.28e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.75e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.31e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139300: loss: 2.33e+02
# loss_eq_m: 4.37e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.76e-04, loss_eq_T: 4.20e+01
# loss_u_eq: 6.32e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139350: loss: 2.28e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.74e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.30e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139400: loss: 2.28e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.21e-01, loss_eq_v: 7.74e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.30e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139450: loss: 2.28e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.73e-04, loss_eq_T: 3.67e+01
# loss_u_eq: 6.30e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139500: loss: 2.30e+02
# loss_eq_m: 4.35e-01, loss_eq_u: 4.29e-01, loss_eq_v: 7.74e-04, loss_eq_T: 3.95e+01
# loss_u_eq: 6.31e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139550: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.73e-04, loss_eq_T: 3.67e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139600: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.72e-04, loss_eq_T: 3.67e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139650: loss: 2.28e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.72e-04, loss_eq_T: 3.72e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139700: loss: 2.27e+02
# loss_eq_m: 4.34e-01, loss_eq_u: 4.24e-01, loss_eq_v: 7.72e-04, loss_eq_T: 3.68e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139750: loss: 2.28e+02
# loss_eq_m: 4.32e-01, loss_eq_u: 4.20e-01, loss_eq_v: 7.71e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139800: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.71e-04, loss_eq_T: 3.66e+01
# loss_u_eq: 6.28e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139850: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.23e-01, loss_eq_v: 7.70e-04, loss_eq_T: 3.66e+01
# loss_u_eq: 6.28e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139900: loss: 2.30e+02
# loss_eq_m: 4.31e-01, loss_eq_u: 4.16e-01, loss_eq_v: 7.71e-04, loss_eq_T: 3.87e+01
# loss_u_eq: 6.29e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.14e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 139950: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.22e-01, loss_eq_v: 7.70e-04, loss_eq_T: 3.65e+01
# loss_u_eq: 6.28e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Iteration 140000: loss: 2.27e+02
# loss_eq_m: 4.33e-01, loss_eq_u: 4.25e-01, loss_eq_v: 7.69e-04, loss_eq_T: 3.71e+01
# loss_u_eq: 6.27e+01, loss_v_eq: 1.36e+01, loss_T_eq: 1.13e+02, loss_p_eq: 0.00e+00, loss_T_nw: 0.00e+00
# Adam training time: 3388.07s

# %%
# model saving
# torch.save(dnn.state_dict(), os.path.join(basepath, model_path, '10layers(36)_THCS 1-head.pkl'))

# %% [markdown]
# ## MAE

# %%
data_2d_wc = {}
feats_keys = {'Ux_Re':'u', 'Uy_Re':'v', 'P_Re':'p', 'T_Re':'T', 'D_Re':'D', 'M_Re':'M', 'K_Re':'k', 'H_Re':'h'}
for k,v in feats_keys.items():
    data_2d_wc[v] = data_2d_dns[k]
    
u = data_2d_wc['u'].to_numpy()  # Nx x Ny
v = data_2d_wc['v'].to_numpy()  # Nx x Ny
p = data_2d_wc['p'].to_numpy()  # Nx x Ny
T = data_2d_wc['T'].to_numpy()  # Nx x Ny
D = data_2d_wc['D'].to_numpy()  # Nx x Ny
M = data_2d_wc['M'].to_numpy()  # Nx x Ny
k = data_2d_wc['k'].to_numpy()  # Nx x Ny
h = data_2d_wc['h'].to_numpy()  # Nx x Ny

X_star_draw = X_star_dns
u_pred, v_pred, p_pred, T_pred, Mt_pred, kt_pred = thcs.predict(X_star_draw[X_star_draw[:, 0] <= 297, :])
D_pred, M_pred, k_pred, h_pred = thcs.predict_prop(T_pred)
uu_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], u_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
vv_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], v_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
pp_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], p_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
TT_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], T_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
MtMt_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], Mt_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
DD_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], D_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
MM_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], M_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
kk_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], k_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
hh_pred = griddata(X_star_draw[X_star_draw[:, 0] <= 297,:2], h_pred.flatten(), (X_dns[X_dns[:, 0] <= 297, :], R_dns[X_dns[:, 0] <= 297, :]), method='cubic')
e_T = abs((TT_pred - T[X_dns[:, 0] <= 297, :])/T[X_dns[:, 0] <= 297, :]).mean()*100
e_u = abs((uu_pred - u[X_dns[:, 0] <= 297, :])/u[X_dns[:, 0] <= 297, :]).mean()*100
e_v = abs((vv_pred - v[X_dns[:, 0] <= 297, :])/v[X_dns[:, 0] <= 297, :]).mean()*100
l_T = (abs(TT_pred - T[X_dns[:, 0] <= 297, :])).mean()
l_u = (abs(uu_pred - u[X_dns[:, 0] <= 297, :])).mean()
l_v = (abs(vv_pred - v[X_dns[:, 0] <= 297, :])).mean()
l_T = (abs(TT_pred - T[X_dns[:,0]<297, :])).mean()
l_u = (abs(uu_pred - u[X_dns[:,0]<297, :])).mean()
l_v = (abs(vv_pred - v[X_dns[:,0]<297, :])).mean()
l_p = (abs(pp_pred - p[X_dns[:,0]<297, :])).mean()
print('Relative error: error_u = %.2f%%, error_v = %.2f%%,  error_T = %.2f%%' %(e_u, e_v, e_T))
print('Loss: Loss_u = %.2e, Loss_v = %.2e,  Loss_T = %.2e' %(l_u, l_v, l_T))
# Out:
# Relative error: error_u = 3.60%, error_v = 1338.08%,  error_T = 0.21%
# Loss: Loss_u = 1.39e-02, Loss_v = 3.16e-04,  Loss_T = 2.26e-03
